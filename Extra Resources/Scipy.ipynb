# %% [markdown]
# # Scipy Library
# SciPy is a scientific computation library that uses NumPy underneath.
# SciPy stands for Scientific Python.
# It provides more utility functions for optimization, stats and signal processing.
# Like NumPy, SciPy is open source so we can use it freely.
# SciPy was created by NumPy's creator Travis Olliphant.

# %%
import scipy

# %%
#For a particular module (here, linear algebra)

import scipy.linalg as la
import numpy as np
a = np.array([[1,2],[3,4]])
a
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
#Determinant

la.det(a)
# Out:
# -2.0

# %%
#Works on lists also

import scipy.linalg as la
import numpy as np
a = ([[1,2],[3,4]])
la.det(a)
# Out:
# -2.0

# %%
#Inverse

import scipy.linalg as la
import numpy as np
a = ([[1,2],[3,4]])
la.inv(a)
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])

# %%
#Inverse of singular ,atrices

import scipy.linalg as la
import numpy as np
a = ([[1,2],[2,4]])
la.inv(a)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-6-4ec2bcc3ecb5> in <module>
#       4 import numpy as np
#       5 a = ([[1,2],[2,4]])
# ----> 6 la.inv(a)
#
# ~\anaconda3\lib\site-packages\scipy\linalg\basic.py in inv(a, overwrite_a, check_finite)
#     961         inv_a, info = getri(lu, piv, lwork=lwork, overwrite_lu=1)
#     962     if info > 0:
# --> 963         raise LinAlgError("singular matrix")
#     964     if info < 0:
#     965         raise ValueError('illegal value in %d-th argument of internal '
#
# LinAlgError: singular matrix

# %%
#Matrix Multiplication

a = ([[1,2],[3,4]])
b=[[5],[6]]
np.dot(a,b)
# Out:
# array([[17],
#        [39]])

# %%
#Solving system of linear equation using inverse

a = ([[1,2],[3,4]])
b=[[5],[6]]
la.inv(a).dot(b)
# Out:
# array([[-4. ],
#        [ 4.5]])

# %%
#Other Way

a = ([[1,2],[3,4]])
b=[[5],[6]]
la.solve(a,b)
# Out:
# array([[-4. ],
#        [ 4.5]])

# %%
#Eigen vector

a = ([[1,2],[3,4]])
b=[[5],[6]]
la.eig(a)
# Out:
# (array([-0.37228132+0.j,  5.37228132+0.j]),
#  array([[-0.82456484, -0.41597356],
#         [ 0.56576746, -0.90937671]]))

# %%
#svd = Singular value decomposition

a = ([[1,2],[3,4]])
b=[[5],[6]]
la.svd(a)
# Out:
# (array([[-0.40455358, -0.9145143 ],
#         [-0.9145143 ,  0.40455358]]),
#  array([5.4649857 , 0.36596619]),
#  array([[-0.57604844, -0.81741556],
#         [ 0.81741556, -0.57604844]]))

# %%
#LU = lower–upper decomposition

a = ([[1,2],[3,4]])
b=[[5],[6]]
la.lu(a)
# Out:
# (array([[0., 1.],
#         [1., 0.]]),
#  array([[1.        , 0.        ],
#         [0.33333333, 1.        ]]),
#  array([[3.        , 4.        ],
#         [0.        , 0.66666667]]))

# %%
import scipy.interpolate as si
import numpy as np
x=np.linspace(0,1,20)
y=np.sin(2*np.pi*x)

import matplotlib.pyplot as plt
plt.plot(x,y)

# %%
import scipy.interpolate as si
import numpy as np
x=np.linspace(0,1,20)
noise=(np.random.random(20)*2-1)*1e-1    
y=np.sin(2*np.pi*x)+noise

import matplotlib.pyplot as plt
plt.plot(x,y)

# %%
import scipy.interpolate as si
import numpy as np
x=np.linspace(0,1,20)
noise=(np.random.random(20)*2-1)*1e-1    
y=np.sin(2*np.pi*x)+noise
cubicmodel=si.interp1d(x,y,kind='cubic')

x1=np.linspace(0,1,10)
cubicresult=cubicmodel(x1)

import matplotlib.pyplot as plt
plt.plot(x,y)
plt.plot(x1,cubicresult,'ro')

# %%
import scipy.interpolate as si
import numpy as np
x=np.linspace(0,1,20)
noise=(np.random.random(20)*2-1)*1e-1    
y=np.sin(2*np.pi*x)+noise
cubicmodel=si.interp1d(x,y,kind='cubic')

x1=np.random.rand(30)
cubicresult=cubicmodel(x1)

import matplotlib.pyplot as plt
plt.plot(x,y)
plt.plot(x1,cubicresult,'ro')

# %%
import scipy.interpolate as si
import numpy as np
x=np.linspace(0,1,20)
noise=(np.random.random(20)*2-1)*1e-1    
y=np.sin(2*np.pi*x)+noise
cubicmodel=si.interp1d(x,y,kind='cubic')

x1=np.random.rand(30)
cubicresult=cubicmodel(x1)

import matplotlib.pyplot as plt
plt.plot(x,y,'b-^')
plt.plot(x1,cubicresult,'ro')

# %%
import scipy.interpolate as si
import numpy as np
x=np.linspace(0,1,5)
noise=(np.random.random(5)*2-1)*1e-1    
y=np.sin(2*np.pi*x)+noise
cubicmodel=si.interp1d(x,y,kind='cubic')

x1=np.random.rand(10)
cubicresult=cubicmodel(x1)

import matplotlib.pyplot as plt
plt.plot(x,y,'b-^')
plt.plot(x1,cubicresult,'ro')

# %%
import scipy.interpolate as si
import numpy as np
x=np.linspace(0,1,20)
noise=(np.random.random(20)*2-1)*1e-1    
y=np.sin(2*np.pi*x)+noise
cubicmodel=si.interp1d(x,y,kind='cubic')

x1=np.random.rand(10)
cubicresult=cubicmodel(x1)

import matplotlib.pyplot as plt
plt.plot(x,y,'b-^')
plt.plot(x1,cubicresult,'ro')

# %%
import scipy.optimize as sp
x=np.linspace(-10,10,200)
def f(x):
    return x**2
sp.minimize(f,x0=-5)
# Out:
#       fun: 6.472220644610882e-16
#  hess_inv: array([[0.5]])
#       jac: array([-3.59799577e-08])
#   message: 'Optimization terminated successfully.'
#      nfev: 8
#       nit: 3
#      njev: 4
#    status: 0
#   success: True
#         x: array([-2.54405594e-08])

# %%
plt.plot(x,f(x))

# %%
import scipy.optimize as sp
x=np.linspace(-10,10,200)
def f(x):
    return x**2+10*np.sin(x)
sp.minimize(f,x0=-5)
res=sp.minimize(f,x0=-5)
res
# Out:
#       fun: -7.945823375615283
#  hess_inv: array([[0.08581214]])
#       jac: array([-5.96046448e-08])
#   message: 'Optimization terminated successfully.'
#      nfev: 18
#       nit: 5
#      njev: 9
#    status: 0
#   success: True
#         x: array([-1.30644001])

# %%
plt.plot(x,f(x))
plt.plot(res['x'],res['fun'],'o')
plt.axhline(0)

# %%
import scipy.optimize as sp
x=np.linspace(-10,10,200)
def f(x):
    return x**2+10*np.sin(x)
sp.minimize(f,x0=-5)
res=sp.minimize(f,x0=2,method='BFGS')
res

plt.plot(x,f(x))
plt.plot(res['x'],res['fun'],'o')
plt.axhline(0)
